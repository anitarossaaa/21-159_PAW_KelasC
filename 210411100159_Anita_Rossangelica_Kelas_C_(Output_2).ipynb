# %% [markdown]
# <a href="https://colab.research.google.com/github/anitarossaaa/21-159_PAW_KelasC/blob/main/210411100159_Anita_Rossangelica_Kelas_C_(Output_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**OUTPUT 2**

# %% [markdown]
# Nama : Anita Rossangelica
# NIM : 210411100159
# Kelas : C (Pengembangan Aplikasi Web)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
<html>
<head>
    <title> Output 2 || 21-159 </title>
    <style>
    h1{
        font-family: Century Gothic;
        color: blueviolet;
        text-align: center;
    }
    h2{
        font-family: Century Gothic;
        color: blue;
        text-align: left;
    }
    h3{
        font-family: Keep on Truckin;
        font-size: 65;
        font-style: italic;
        color: maroon;
        text-align: center;
    }
    body{
        font-family: Edoms Handwritting Normal;
        font-size: 22
    }
    </style>
</head>
<body bgcolor="cornflowerblue">
    <script>
        //Prompt JavaScript untuk menampilkan identitas
            var nama = prompt ("Nama saya adalah: ");
            var nim = prompt ("N I M saya adalah: ");
            document.write("Hai semua! Kembali bersama saya "+nama+" dengan NIM "+nim+". <br>");
            document.write("Berikut ini adalah hasil belajar saya selama kuliah ke-2 atau output 2 saya pada kelas Pengembangan Aplikasi Web C :");
    </script>
    <h1> OUTPUT 2 KULIAH PAW 29 AGUSTUS 2022 </h1> <br>
<h2> Perulangan For </h2>
    <?php
        for ($iterasi=0; $iterasi < 3 ; $iterasi++){
        echo("<br> Ini adalah hasil belajar saya mengenai perulangan for. Sekarang perulangan ke- ".$iterasi);
        }
    ?>

<h2> Tipe data pada PHP : 1. STRING </h2>
    <?php
        echo("x atau urutan 1 merupakan variabel string yang berisi nama <br> y atau urutan 2 merupakan variabel string yang berisi institusi <br><br>");
        $x = "Anita Rossangelica";
        $y = 'Universitas Trunojoyo Madura';

        echo $x;
        echo "<br>";
        echo $y;
        echo("<br><br> Nama saya ".$x.". Saya berasal dari institusi ".$y);
    ?>

<h2> Tipe data pada PHP : 2. INTEGER </h2>
    <?php
        echo("Ini berisikan NIM saya yang dimana menggunakan fungsi var_dump untuk mencetak output pada browser yang berisikan nilai variabel <br><br>");
        $nim = 210411100159;
        var_dump($nim);
    ?>

<h2> Tipe data pada PHP : 3. ARRAY </h2>
    <?php
        echo("Ini berisikan nama panggilan saya yang dimana saya susun dan saya tampilkan dalam array <br><br>");
        $panggilan =array("Anita","Nita","Kak Nita","Ayangku","Adek Mumu");
        $jumlah = count($panggilan);
        for($iterasi=0; $iterasi<$jumlah; $iterasi++)
        print("\$panggilan[$iterasi] : $panggilan[$iterasi] <br>\n");
    ?>

<h3> "Adanya error itu untuk diatasi dan dihadapi, bukan untuk dihindari apalagi ditinggal pergi~ Anita.R 2022" </h3>
</body>
</html>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
